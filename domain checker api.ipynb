# %%
import requests

# %%
business_name = "m0nica"

# %%
response = requests.get('https://api.domainsdb.info/search?query=' + business_name + '&tld=all')
data = response.json()

# %%
print(data)
# Out:
# {'time': 0, 'total': 0}

# %%
data['total']
# Out:
# 0
